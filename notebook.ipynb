# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Atika Dwi Saputri]
# - **Email:** [atikadwisaputri18@gmail.com]
# - **ID Dicoding:** [atika_dwi_18]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1.  Bagaimana tren penggunaan sepeda setiap bulannya?
# 2.  Apakah cuaca memengaruhi jumlah pengguna sepeda?
# 3.  Bagaimana perbedaan penggunaan sepeda pada hari kerja dibandingkan hari libur?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. Pembersihan Data (Cleaning Data)
# Tidak ada missing values atau duplikat, sehingga tidak ada tindakan khusus

# 3. Pertanyaan Bisnis:
# 1. Bagaimana tren penggunaan sepeda setiap bulannya?
# 2. Apakah cuaca memengaruhi jumlah pengguna sepeda?
# 3. Bagaimana perbedaan penggunaan sepeda pada hari kerja dibandingkan hari libur?

# 4. Exploratory Data Analysis (EDA) dan Visualisasi

# Pertanyaan 1: Bagaimana tren penggunaan sepeda setiap bulannya?
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='month', y='cnt', ci=None, marker="o")
plt.title('Tren Penggunaan Sepeda Setiap Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# Pertanyaan 2: Apakah cuaca memengaruhi jumlah pengguna sepeda?
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='weathersit', y='cnt')
plt.title('Pengaruh Cuaca Terhadap Jumlah Pengguna Sepeda')
plt.xlabel('Kategori Cuaca (1: Cerah, 2: Mendung, 3: Hujan)')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.grid(True)
plt.show()

# Pertanyaan 3: Bagaimana perbedaan penggunaan sepeda pada hari kerja dibandingkan hari libur?
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='workingday', y='cnt')
plt.title('Penggunaan Sepeda Pada Hari Kerja vs Hari Libur')
plt.xlabel('Hari Kerja (0: Libur, 1: Kerja)')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
#  16  month       731 non-null    int32
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(11)
# memory usage: 94.4 KB
# None
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
file_path = '/content/day.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ### Assessing Data

# %%
df['dteday'] = pd.to_datetime(df['dteday'])
df['month'] = df['dteday'].dt.month
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
#  16  month       731 non-null    int32
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(11)
# memory usage: 94.4 KB
# None

# %% [markdown]
# ## Cleaning Data

# %%
print("Missing values per kolom:\n", df.isnull().sum())
# Out:
# Missing values per kolom:
#  instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# month         0
# dtype: int64

# %%
print("Jumlah duplikat: ", df.duplicated().sum())
# Out:
# Jumlah duplikat:  0

# %%
print(df.describe())
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %% [markdown]
# ## **Cleaning Data**

# %% [markdown]
# ### Tidak ada missing values atau duplikat, sehingga tidak ada tindakan khusus

# %% [markdown]
# ## **Exploratory Data Analysis (EDA) dan Visualisasi**

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# Bagaimana tren penggunaan sepeda setiap bulannya?

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='month', y='cnt', ci=None, marker="o")
plt.title('Tren Penggunaan Sepeda Setiap Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()
# Out:
# <ipython-input-12-81d71743e9b7>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x='month', y='cnt', ci=None, marker="o")

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# Apakah cuaca memengaruhi jumlah pengguna sepeda?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='weathersit', y='cnt')
plt.title('Pengaruh Cuaca Terhadap Jumlah Pengguna Sepeda')
plt.xlabel('Kategori Cuaca (1: Cerah, 2: Mendung, 3: Hujan)')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ### Pertanyaan 3:

# %% [markdown]
# Bagaimana perbedaan penggunaan sepeda pada hari kerja dibandingkan hari libur?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='workingday', y='cnt')
plt.title('Penggunaan Sepeda Pada Hari Kerja vs Hari Libur')
plt.xlabel('Hari Kerja (0: Libur, 1: Kerja)')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# # Conclusion

# %% [markdown]
# *   Conclution pertanyaan 1:  Pada grafik di atas menunjukkan jumlah pengguna
# sepeda dari bulan ke bulan. Kita bisa lihat kalau penggunaan sepeda naik terus sampai bulan ke-7, lalu mulai turun. Ini artinya, banyak orang mulai rajin bersepeda dari awal tahun sampai pertengahan tahun. Setelah itu, jumlahnya berkurang lagi dari bulan oktober sampai desember.
# *   Conclution pertanyaan 2: Dari boxplot di atas kita bisa menyimpulkan bahwa cuaca memiliki pengaruh yang cukup besar terhadap minat orang untuk bersepeda. Cuaca cerah menjadi faktor utama yang mendorong orang untuk memilih sepeda sebagai alat transportasi atau aktivitas rekreasi.
# *  Conclution pertanyaan 3: Boxplot di atas membandingkan jumlah pengguna sepeda pada hari kerja dan hari libur. Terlihat bahwa tidak ada perbedaan yang signifikan antara jumlah pengguna sepeda pada hari kerja dan hari libur. Artinya, baik di hari kerja maupun hari libur, jumlah orang yang bersepeda cenderung sama.kita bisa menyimpulkan bahwa hari kerja atau hari libur tidak terlalu mempengaruhi jumlah orang yang bersepeda. Faktor lain mungkin lebih dominan dalam menentukan jumlah pengguna sepeda.

# %% [markdown]
# ## Export Data untuk Dashboard

# %%
main_data = df.copy()
main_data.to_csv('main_data.csv', index=False)
